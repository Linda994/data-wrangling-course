# %%
import whyqd as _w
schema = _w.Schema()

details = {
        "name": "human-development-report",
        "title": "UN Human Development Report 2007 - 2008",
        "description": """
        En 1990, le premier rapport sur le développement humain a introduit une nouvelle approche pour
        faire progresser le bien-être de l'homme. Le développement humain - ou l'approche du développement humain - consiste à
        l'élargissement de la richesse de la vie humaine, plutôt que simplement de la richesse de l'économie dans laquelle
        les êtres humains vivent. Il s'agit d'une approche axée sur les personnes, leurs possibilités et leurs choix."""
}
schema = _w.Schema()
schema.set_details(**details)

# %%
fields = [
    {
        "name": "Country Name",
        "title": "Country Name",
        "type": "string",
        "description": "Official country names.",
        "constraints": {
            "required": True
        }
    },
    {
        "name": "HDI Category",
        "title": "HDI Category",
        "type": "string",
        "description": "Human Development Index Category derived from the HDI Rank.",
    },
    {
        "name": "Indicator Name",
        "title": "Indicator Name",
        "type": "string",
        "description": "Indicator described in the data series.",
    },
    {
        "name": "Reference",
        "title": "Reference",
        "type": "string",
        "description": "Reference to data source.",
    },
    {
        "name": "Year",
        "title": "Year",
        "type": "year",
        "description": "Year of release.",
    },
    {
        "name": "Values",
        "title": "Values",
        "type": "number",
        "description": "Value for the Year and Indicator Name.",
        "constraints": {
            "required": True
        }
    },
]
for field in fields:
    schema.set_field(**field)

# %%
schema.field("country_name")
# Out:
# {'name': 'country_name',
#  'type': 'string',
#  'constraints': {'required': True},
#  'title': 'Country Name',
#  'description': 'Official country names.'}

# %%
directory = "C:/Users/CHARLENE LINDA/Desktop/"
filename = "human-development-report-schema"
schema.save(directory, filename=filename)
# Out:
# True

# %%
### Les importations et paramètres suivants vous permettent d'obtenir un large éventail de résultats pour vos tableaux
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))

import numpy as np
import whyqd as _w

SCHEMA_SOURCE = "C:/Users/CHARLENE LINDA/Desktop/human-development-report-schema.json"
DIRECTORY = "C:/Users/CHARLENE LINDA/Desktop/"
INPUT_DATA = ["C:/Users/CHARLENE LINDA/Downloads/HDR 2007-2008 Table 11.xlsx"]
method = _w.Method(SCHEMA_SOURCE, directory=DIRECTORY, input_data=INPUT_DATA)
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
print(method.help())
# Out:
# **whyqd** provides data wrangling simplicity, complete audit transparency, and at speed.
#
# To get help, type:
#
# 	>>> method.help(option)
#
# Where `option` can be any of:
#
# 	status
# 	merge
# 	structure
# 	category
# 	filter
# 	transform
#
# `status` will return the current method status, and your mostly likely next steps. The other options
# will return methodology, and output of that option's result (if appropriate). The `error` will
# present an error trace and attempt to guide you to fix the process problem.
#
# Current method status: `Ready to Merge`

# %%
print(method.print_input_data())
# Out:
# Data id: fbe38926-ba04-4930-b100-505185b5e042
# Original source: C:/Users/CHARLENE LINDA/Downloads/HDR 2007-2008 Table 11.xlsx
#
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..  Unnamed: 0                                      Unnamed: 1    Unnamed: 2  Unnamed: 3                   Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27    Unnamed: 28    Unnamed: 29    Unnamed: 30    Unnamed: 31    Unnamed: 32
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0  nan                                                    nan           nan  … to acquire knowledge ….           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1  11  Commitment to education: public spending           nan           nan  nan                                 nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2  nan                                                    nan           nan  nan                                 nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============

# %%
method.default_morph_types
# Out:
# ['CATEGORISE', 'DEBLANK', 'DEDUPE', 'DELETE', 'MELT', 'REBASE', 'RENAME']

# %%
method.default_morph_settings("CATEGORISE")
# Out:
# {'name': 'CATEGORISE',
#  'title': 'Categorise',
#  'type': 'morph',
#  'description': 'Convert row-level categories into column categorisations.',
#  'structure': ['rows', 'column_names']}

# %%
# Utilisez _id, ou une autre variable, puisque `id` est un terme protégé par Python
_id = method.input_data[0]["id"]
df = method.input_dataframe(_id)
df.head()
# Out:
#                                      Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                           NaN        NaN        NaN
# 1  11  Commitment to education: public spending        NaN        NaN
# 2                                           NaN        NaN        NaN
# 3                                           NaN        NaN        NaN
# 4                                           NaN        NaN        NaN
#
#                            Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0           … to acquire knowledge ….        NaN        NaN        NaN
# 1                                 NaN        NaN        NaN        NaN
# 2                                 NaN        NaN        NaN        NaN
# 3  Public expenditure on education           NaN        NaN        NaN
# 4                       As a % of GDP        NaN        NaN        NaN
#
#                                Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                                     NaN        NaN        NaN  ...
# 1                                     NaN        NaN        NaN  ...
# 2                                     NaN        NaN        NaN  ...
# 3                                     NaN        NaN        NaN  ...
# 4  As a % of total government expenditure        NaN        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]

# %%
#method.reset_input_data_morph(_id)

# %%
method.add_input_data_morph(_id, ["REBASE", 7])

# %%
df.tail(30)
# Out:
#                                             Unnamed: 0  \
# 165                              LOW HUMAN DEVELOPMENT
# 166                                                156
# 167                                                157
# 168                                                158
# 169                                                159
# 170                                                160
# 171                                                161
# 172                                                162
# 173                                                163
# 174                                                164
# 175                                                165
# 176                                                166
# 177                                                167
# 178                                                168
# 179                                                169
# 180                                                170
# 181                                                171
# 182                                                172
# 183                                                173
# 184                                                174
# 185                                                175
# 186                                                176
# 187                                                177
# 188                                                NaN
# 189                                                NaN
# 190                                              NOTES
# 191                                                NaN
# 192  a. Expenditures by level may not sum to 100 as...
# 193                                                NaN
# 194  SOURCES\nColumns 1–4, 7, 9 and 10: UNESCO Inst...
#
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 165                                 NaN        NaN        NaN        NaN
# 166                             Senegal        NaN        3.9        NaN
# 167                             Eritrea        NaN         ..        NaN
# 168                             Nigeria        NaN        0.9        NaN
# 169       Tanzania (United Republic of)        NaN        2.8        NaN
# 170                              Guinea        NaN        2.0        NaN
# 171                              Rwanda        NaN         ..        NaN
# 172                              Angola        NaN         ..        NaN
# 173                               Benin        NaN         ..        NaN
# 174                              Malawi        NaN        3.2        NaN
# 175                              Zambia        NaN        2.8        NaN
# 176                       Côte d'Ivoire        NaN         ..        NaN
# 177                             Burundi        NaN        3.5        NaN
# 178  Congo (Democratic Republic of the)        NaN         ..        NaN
# 179                            Ethiopia        NaN        2.4        NaN
# 180                                Chad        NaN        1.6        NaN
# 181            Central African Republic        NaN        2.2        NaN
# 182                          Mozambique        NaN         ..        NaN
# 183                                Mali        NaN         ..        NaN
# 184                               Niger        NaN        3.3        NaN
# 185                       Guinea-Bissau        NaN         ..        NaN
# 186                        Burkina Faso        NaN        2.6        NaN
# 187                        Sierra Leone        NaN         ..        NaN
# 188                                 NaN        NaN        NaN        NaN
# 189                                 NaN        NaN        NaN        NaN
# 190                                 NaN        NaN        NaN        NaN
# 191                                 NaN        NaN        NaN        NaN
# 192                                 NaN        NaN        NaN        NaN
# 193                                 NaN        NaN        NaN        NaN
# 194                                 NaN        NaN        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 23  \
# 165        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 166        5.4        NaN       26.9        NaN       18.9  ...         NaN
# 167        5.4        NaN         ..        NaN         ..  ...         NaN
# 168         ..        NaN         ..        NaN         ..  ...         NaN
# 169        2.2        c,e       11.4        NaN         ..  ...         NaN
# 170        2.0        NaN       25.7        NaN       25.6  ...         NaN
# 171        3.8        NaN         ..        NaN       12.2  ...         NaN
# 172        2.6        c,e         ..        NaN        6.4  ...         NaN
# 173        3.5          e         ..        NaN       14.1  ...         NaN
# 174        5.8        NaN       11.1        NaN       24.6  ...         NaN
# 175        2.0        NaN        7.1        NaN       14.8  ...         NaN
# 176        4.6        c,e         ..        NaN       21.5  ...         NaN
# 177        5.1        NaN       17.7        NaN       17.7  ...         NaN
# 178         ..        NaN         ..        NaN         ..  ...         NaN
# 179        6.1          g        9.4        NaN       17.5  ...         NaN
# 180        2.1        NaN         ..        NaN       10.1  ...         NaN
# 181         ..        NaN         ..        NaN         ..  ...         NaN
# 182        3.7        NaN         ..        NaN       19.5  ...         NaN
# 183        4.3        NaN         ..        NaN       14.8  ...         NaN
# 184        2.3        NaN       18.6        NaN         ..  ...         NaN
# 185        5.2          c         ..        NaN       11.9  ...         NaN
# 186        4.7        NaN         ..        NaN       16.6  ...         NaN
# 187        4.6          e         ..        NaN         ..  ...         NaN
# 188        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 189        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 190        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 191        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 192        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 193        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 194        NaN        NaN        NaN        NaN        NaN  ...         NaN
#
#     Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 165         NaN         NaN         NaN         NaN         NaN         NaN
# 166         NaN         NaN         NaN         NaN         NaN         NaN
# 167         NaN         NaN         NaN         NaN         NaN         NaN
# 168         NaN         NaN         NaN         NaN         NaN         NaN
# 169         NaN         NaN         NaN         NaN         NaN         NaN
# 170         NaN         NaN         NaN         NaN         NaN         NaN
# 171         NaN         NaN         NaN         NaN         NaN         NaN
# 172         NaN         NaN         NaN         NaN         NaN         NaN
# 173         NaN         NaN         NaN         NaN         NaN         NaN
# 174         NaN         NaN         NaN         NaN         NaN         NaN
# 175         NaN         NaN         NaN         NaN         NaN         NaN
# 176         NaN         NaN         NaN         NaN         NaN         NaN
# 177         NaN         NaN         NaN         NaN         NaN         NaN
# 178         NaN         NaN         NaN         NaN         NaN         NaN
# 179         NaN         NaN         NaN         NaN         NaN         NaN
# 180         NaN         NaN         NaN         NaN         NaN         NaN
# 181         NaN         NaN         NaN         NaN         NaN         NaN
# 182         NaN         NaN         NaN         NaN         NaN         NaN
# 183         NaN         NaN         NaN         NaN         NaN         NaN
# 184         NaN         NaN         NaN         NaN         NaN         NaN
# 185         NaN         NaN         NaN         NaN         NaN         NaN
# 186         NaN         NaN         NaN         NaN         NaN         NaN
# 187         NaN         NaN         NaN         NaN         NaN         NaN
# 188         NaN         NaN         NaN         NaN         NaN         NaN
# 189         NaN         NaN         NaN         NaN         NaN         NaN
# 190         NaN         NaN         NaN         NaN         NaN         NaN
# 191         NaN         NaN         NaN         NaN         NaN         NaN
# 192         NaN         NaN         NaN         NaN         NaN         NaN
# 193         NaN         NaN         NaN         NaN         NaN         NaN
# 194         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 30 Unnamed: 31 Unnamed: 32
# 165         NaN         NaN         NaN
# 166         NaN         NaN         NaN
# 167         NaN         NaN         NaN
# 168         NaN         NaN         NaN
# 169         NaN         NaN         NaN
# 170         NaN         NaN         NaN
# 171         NaN         NaN         NaN
# 172         NaN         NaN         NaN
# 173         NaN         NaN         NaN
# 174         NaN         NaN         NaN
# 175         NaN         NaN         NaN
# 176         NaN         NaN         NaN
# 177         NaN         NaN         NaN
# 178         NaN         NaN         NaN
# 179         NaN         NaN         NaN
# 180         NaN         NaN         NaN
# 181         NaN         NaN         NaN
# 182         NaN         NaN         NaN
# 183         NaN         NaN         NaN
# 184         NaN         NaN         NaN
# 185         NaN         NaN         NaN
# 186         NaN         NaN         NaN
# 187         NaN         NaN         NaN
# 188         NaN         NaN         NaN
# 189         NaN         NaN         NaN
# 190         NaN         NaN         NaN
# 191         NaN         NaN         NaN
# 192         NaN         NaN         NaN
# 193         NaN         NaN         NaN
# 194         NaN         NaN         NaN
#
# [30 rows x 33 columns]

# %%
# On obtient la valeur du dernier élément de l'index, puis on ajoute 1 pour créer l'intervalle
rows = [int(i) for i in np.arange(190, df.index[-1]+1)]
method.add_input_data_morph(_id, ["DELETE", rows])

# %%
columns=[
    "HDI rank",
    "country",
    "PEE _% _GDP_1991",
    "PEE _% _GDP_2002_2005b",
    "Reference 1",
    "PEE _% _TGE_1991 ",
    "Reference 2",
    "PEE _% _TGE_2002_2005b",
    "Reference 3",
    "current_PEE_by_primary_1991",
    "Reference 4",
    "current_PEE_by_primary_2002_2005b",
    "Reference 5",
    "current_PEE_by_secondary_1991",
    "Reference 6",
    "current_PEE_by_secondary_2002_2005b",
    "Reference 7",
    "current_PEE_by_Tertiary_1991",
    "Reference 8",
    "current_PEE_by_Tertiary_2002_2005b",
    "Reference 9"
]
method.add_input_data_morph(_id, ["RENAME",columns])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#                   HDI rank    country PEE _% _GDP_1991 PEE _% _GDP_2002_2005b  \
# 8   HIGH HUMAN DEVELOPMENT        NaN              NaN                    NaN
# 9                        1    Iceland               ..                    8.1
# 10                       2     Norway              7.1                    7.7
# 11                       3  Australia              4.9                    4.7
# 12                       4     Canada              6.5                    5.2
#
#    Reference 1 PEE _% _TGE_1991  Reference 2 PEE _% _TGE_2002_2005b  \
# 8          NaN               NaN         NaN                    NaN
# 9          NaN                ..         NaN                   16.6
# 10         NaN              14.6         NaN                   16.6
# 11         NaN              14.8         NaN                   13.3
# 12         NaN              14.2         NaN                   12.5
#
#    Reference 3 current_PEE_by_primary_1991  ...  \
# 8          NaN                         NaN  ...
# 9          NaN                          ..  ...
# 10         NaN                          38  ...
# 11           c                          ..  ...
# 12           c                          ..  ...
#
#    current_PEE_by_primary_2002_2005b Reference 5  \
# 8                                NaN         NaN
# 9                                 40         NaN
# 10                                28         NaN
# 11                                34         NaN
# 12                                ..         NaN
#
#    current_PEE_by_secondary_1991 Reference 6  \
# 8                            NaN         NaN
# 9                             ..         NaN
# 10                            27         NaN
# 11                            ..         NaN
# 12                            68         NaN
#
#    current_PEE_by_secondary_2002_2005b Reference 7  \
# 8                                  NaN         NaN
# 9                                   35         NaN
# 10                                  35         NaN
# 11                                  41         NaN
# 12                                  ..         NaN
#
#    current_PEE_by_Tertiary_1991 Reference 8  \
# 8                           NaN         NaN
# 9                            ..         NaN
# 10                           16         NaN
# 11                           ..         NaN
# 12                           31         NaN
#
#    current_PEE_by_Tertiary_2002_2005b Reference 9
# 8                                 NaN         NaN
# 9                                  19         NaN
# 10                                 33         NaN
# 11                                 25         NaN
# 12                                 34           e
#
# [5 rows x 21 columns]

# %%
# Obtenir les indices des lignes de données catégorielles
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
rows = df[df["HDI rank"].isin(hdi_categories)].index
method.add_input_data_morph(_id, ["CATEGORISE", rows, "HDI category"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e976575a9113> in <module>
#       2 hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
#       3 rows = df[df["HDI rank"].isin(hdi_categories)].index
# ----> 4 method.add_input_data_morph(_id, ["CATEGORISE", rows, "HDI category"])
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in add_input_data_morph(self, _id, new_morph)
#    1128                         input_source = self._get_input_data_morph(_id)
#    1129                 df = self.input_dataframe(_id)
# -> 1130                 input_source["morph"] = self.add_morph(df=df, new_morph=new_morph, morph_methods=input_source.get("morph"))
#    1131                 self._set_input_data_morph(input_source)
#    1132
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in add_morph(self, df, new_morph, morph_methods)
#    1251                 if not morph.validates(df=df, **parameters):
#    1252                         e = F"Task morph `{morph.name}` has invalid structure `{morph.structure}`."
# -> 1253                         raise ValueError(e)
#    1254                 morph_settings = morph.settings
#    1255                 morph_settings["id"] = str(uuid.uuid4())
#
# ValueError: Task morph `CATEGORISE` has invalid structure `['rows', 'column_names']`.

# %%
type(rows)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
method.add_input_data_morph(_id, ["CATEGORISE", list(rows), "HDI category"])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#    HDI rank    country PEE _% _GDP_1991 PEE _% _GDP_2002_2005b Reference 1  \
# 9         1    Iceland               ..                    8.1         NaN
# 10        2     Norway              7.1                    7.7         NaN
# 11        3  Australia              4.9                    4.7         NaN
# 12        4     Canada              6.5                    5.2         NaN
# 13        5    Ireland              5.0                    4.8         NaN
#
#    PEE _% _TGE_1991  Reference 2 PEE _% _TGE_2002_2005b Reference 3  \
# 9                 ..         NaN                   16.6         NaN
# 10              14.6         NaN                   16.6         NaN
# 11              14.8         NaN                   13.3           c
# 12              14.2         NaN                   12.5           c
# 13               9.7         NaN                   14.0         NaN
#
#    current_PEE_by_primary_1991  ... Reference 5 current_PEE_by_secondary_1991  \
# 9                           ..  ...         NaN                            ..
# 10                          38  ...         NaN                            27
# 11                          ..  ...         NaN                            ..
# 12                          ..  ...         NaN                            68
# 13                          37  ...         NaN                            40
#
#    Reference 6 current_PEE_by_secondary_2002_2005b Reference 7  \
# 9          NaN                                  35         NaN
# 10         NaN                                  35         NaN
# 11         NaN                                  41         NaN
# 12         NaN                                  ..         NaN
# 13         NaN                                  43         NaN
#
#    current_PEE_by_Tertiary_1991 Reference 8  \
# 9                            ..         NaN
# 10                           16         NaN
# 11                           ..         NaN
# 12                           31         NaN
# 13                           21         NaN
#
#    current_PEE_by_Tertiary_2002_2005b Reference 9            HDI category
# 9                                  19         NaN  HIGH HUMAN DEVELOPMENT
# 10                                 33         NaN  HIGH HUMAN DEVELOPMENT
# 11                                 25         NaN  HIGH HUMAN DEVELOPMENT
# 12                                 34           e  HIGH HUMAN DEVELOPMENT
# 13                                 24         NaN  HIGH HUMAN DEVELOPMENT
#
# [5 rows x 22 columns]

# %%
columns=[
    "HDI rank",
    "PEE _% _GDP_1991",
    "PEE _% _GDP_2002_2005b",
    "PEE _% _TGE_1991 ",
    "PEE _% _TGE_2002_2005b",
    "current_PEE_by_primary_1991",
    "current_PEE_by_primary_2002_2005b",
    "current_PEE_by_secondary_1991",
    "current_PEE_by_secondary_2002_2005b",
    "current_PEE_by_Tertiary_1991",
    "current_PEE_by_Tertiary_2002_2005b",
]
method.add_input_data_morph(_id, ["MELT", columns, ["Indicator Name", "Indicator Value"]])

# %%
columns=[
    "Reference 1",
    "Reference 2",
    "Reference 3",
    "Reference 4",
    "Reference 5",
    "Reference 6",
    "Reference 7",
    "Reference 8",
    "Reference 9"
]
method.add_input_data_morph(_id, ["MELT", columns, ["Reference Name", "Reference"]])

# %%
method.add_input_data_morph(_id, ["DEBLANK"])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#   Indicator Value Indicator Name            HDI category    country  \
# 0               1       HDI rank  HIGH HUMAN DEVELOPMENT    Iceland
# 1               2       HDI rank  HIGH HUMAN DEVELOPMENT     Norway
# 2               3       HDI rank  HIGH HUMAN DEVELOPMENT  Australia
# 3               4       HDI rank  HIGH HUMAN DEVELOPMENT     Canada
# 4               5       HDI rank  HIGH HUMAN DEVELOPMENT    Ireland
#
#   Reference Name Reference
# 0    Reference 1       NaN
# 1    Reference 1       NaN
# 2    Reference 1       NaN
# 3    Reference 1       NaN
# 4    Reference 1       NaN

# %%
print(method.help("merge"))
# Out:
# `merge` will join, in order from right to left, your input data on a common column.
#
# To add input data, where `input_data` is a filename, or list of filenames:
#
# 	>>> method.add_input_data(input_data)
#
# To remove input data, where `id` is the unique id for that input data:
#
# 	>>> method.remove_input_data(id)
#
# Prepare an `order_and_key` list, where each dict in the list has:
#
# 	{{id: input_data id, key: column_name for merge}}
#
# Run the merge by calling (and, optionally - if you need to overwrite an existing merge - setting
# `overwrite_working=True`):
#
# 	>>> method.merge(order_and_key, overwrite_working=True)
#
# To view your existing `input_data`:
#
# 	>>> method.input_data
#
#
# Data id: fbe38926-ba04-4930-b100-505185b5e042
# Original source: C:/Users/CHARLENE LINDA/Downloads/HDR 2007-2008 Table 11.xlsx
#
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..  Unnamed: 0                                      Unnamed: 1    Unnamed: 2  Unnamed: 3                   Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27    Unnamed: 28    Unnamed: 29    Unnamed: 30    Unnamed: 31    Unnamed: 32
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0  nan                                                    nan           nan  … to acquire knowledge ….           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1  11  Commitment to education: public spending           nan           nan  nan                                 nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2  nan                                                    nan           nan  nan                                 nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ============================================  ============  ============  =========================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#
#
# Current method status: `Ready to Merge`

# %%
print(method.help("structure"))
# Out:
# `structure` is the core of the wrangling process and is the process where you define the actions
# which must be performed to restructure your working data.
#
# Create a list of methods of the form:
#
# 	{
# 		"schema_field1": ["action", "column_name1", ["action", "column_name2"]],
# 		"schema_field2": ["action", "column_name1", "modifier", ["action", "column_name2"]],
# 	}
#
# The format for defining a `structure` is as follows::
#
# 	[action, column_name, [action, column_name]]
#
# e.g.::
#
# 	["CATEGORISE", "+", ["ORDER", "column_1", "column_2"]]
#
# This permits the creation of quite expressive wrangling structures from simple building
# blocks.
#
# The schema for this method consists of the following terms:
#
# ['country_name', 'hdi_category', 'indicator_name', 'reference', 'year', 'values']
#
# The actions:
#
# ['CALCULATE', 'CATEGORISE', 'JOIN', 'NEW', 'ORDER', 'ORDER_NEW', 'ORDER_OLD', 'RENAME']
#
# The columns from your working data:
#
# []
#
#
# Current method status: `Ready to Merge`

# %%
structure = {
    "country_name": ["RENAME", "Country"],
    "hdi_category": ["RENAME", "HDI category"],
    "indicator_name": ["RENAME", "Indicator Name"],
    "reference": ["RENAME", "Reference"],
    "values": ["RENAME", "Indicator Value"],
}

# %%
method.set_structure(**structure)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-31-e58ae0fa009b> in <module>
# ----> 1 method.set_structure(**structure)
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in set_structure(self, **kwargs)
#     467 												"READY_TRANSFORM", "PROCESS_COMPLETE", "STRUCTURE_ERROR"]:
#     468                         e = "Current status: `{}` - performing `set_structure` not permitted.".format(self.status)
# --> 469                         raise PermissionError(e)
#     470                 self.validate_merge
#     471                 category_check = False
#
# PermissionError: Current status: `Ready to Merge` - performing `set_structure` not permitted.

# %%
method.transform(overwrite_output=True)
FILENAME = "hdi_report_exercise"
method.save(directory, filename=FILENAME, overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-32-3ba97b5d72be> in <module>
# ----> 1 method.transform(overwrite_output=True)
#       2 FILENAME = "hdi_report_exercise"
#       3 method.save(directory, filename=FILENAME, overwrite=True)
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in transform(self, overwrite_output, filetype)
#     780                 if self._status in STATUS_CODES.keys() - ["READY_FILTER", "READY_TRANSFORM", "PROCESS_COMPLETE"]:
#     781                         e = "Current status: `{}` - performing `transform` is not permitted.".format(self.status)
# --> 782                         raise PermissionError(e)
#     783                 self.validates
#     784                 if self.schema_settings.get("output_data",{}).get("checksum") and not overwrite_output:
#
# PermissionError: Current status: `Ready to Merge` - performing `transform` is not permitted.

# %%
method.input_data_morphs(_id)
# Out:
# [{'838271bc-0558-4c0f-a127-b455cb214c6e': ['DEBLANK']},
#  {'0b85cf8f-d12b-4fb9-a667-cd64873a63d4': ['DEDUPE']},
#  {'8a607f90-d359-4a0b-a338-94ad1498bd4c': ['REBASE', [7]]},
#  {'c388080e-128a-412f-a984-f361c3eb791b': ['DELETE',
#    [190, 191, 192, 193, 194]]},
#  {'5c6a9a31-7391-4b0a-bda9-ebebe932fdf6': ['RENAME',
#    ['HDI rank',
#     'country',
#     'PEE _% _GDP_1991',
#     'PEE _% _GDP_2002_2005b',
#     'Reference 1',
#     'PEE _% _TGE_1991 ',
#     'Reference 2',
#     'PEE _% _TGE_2002_2005b',
#     'Reference 3',
#     'current_PEE_by_primary_1991',
#     'Reference 4',
#     'current_PEE_by_primary_2002_2005b',
#     'Reference 5',
#     'current_PEE_by_secondary_1991',
#     'Reference 6',
#     'current_PEE_by_secondary_2002_2005b',
#     'Reference 7',
#     'current_PEE_by_Tertiary_1991',
#     'Reference 8',
#     'current_PEE_by_Tertiary_2002_2005b',
#     'Reference 9']]},
#  {'cf043453-c24c-41e3-9e9d-9c5e8aa6f353': ['CATEGORISE',
#    [8, 79, 165],
#    ['HDI category']]},
#  {'afaf9d32-3c90-45db-b8c4-953e837360ca': ['MELT',
#    [['Reference 1',
#      'Reference 7',
#      'Reference 2',
#      'Reference 6',
#      'HDI category',
#      'Reference 8',
#      'Reference 5',
#      'Reference 4',
#      'country',
#      'Reference 9',
#      'Reference 3'],
#     ['HDI rank',
#      'PEE _% _GDP_1991',
#      'PEE _% _GDP_2002_2005b',
#      'PEE _% _TGE_1991 ',
#      'PEE _% _TGE_2002_2005b',
#      'current_PEE_by_primary_1991',
#      'current_PEE_by_primary_2002_2005b',
#      'current_PEE_by_secondary_1991',
#      'current_PEE_by_secondary_2002_2005b',
#      'current_PEE_by_Tertiary_1991',
#      'current_PEE_by_Tertiary_2002_2005b']],
#    ['Indicator Name', 'Indicator Value']]},
#  {'318b4bfb-99bc-4aba-9f6e-b217b4277cc0': ['MELT',
#    [['Indicator Value', 'Indicator Name', 'HDI category', 'country'],
#     ['Reference 1',
#      'Reference 2',
#      'Reference 3',
#      'Reference 4',
#      'Reference 5',
#      'Reference 6',
#      'Reference 7',
#      'Reference 8',
#      'Reference 9']],
#    ['Reference Name', 'Reference']]},
#  {'95ad5939-556b-411a-97bd-5d3a318a7e9a': ['DEBLANK']}]

# %%
# %time method.validates
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in validates(self)
#    2116                 self.validate_input_data
#    2117                 self.validate_merge_data
# -> 2118                 self.validate_merge
#    2119                 self.validate_structure
#    2120                 self.validate_category
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in validate_merge(self)
#    1917                 # Save temporary file ... has to save & load for checksum validation
#    1918                 _id = str(uuid.uuid4())
# -> 1919                 filetype = self.schema_settings["working_data"]["file"].split(".")[-1]
#    1920                 filename = "".join([_id, ".", filetype])
#    1921                 source = self.directory + filename
#
# KeyError: 'working_data'

# %%
import pandas as pd
import numpy as np

source = "C:/Users/CHARLENE LINDA/Desktop/education_public_spending_per_level_of_HDI.csv"

df = pd.read_csv(source)
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-39-ad40e8b6c2f1> in <module>
#       4 source = "C:/Users/CHARLENE LINDA/Desktop/education_public_spending_per_level_of_HDI.csv"
#       5
# ----> 6 df = pd.read_csv(source)
#       7 df.head()
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 1: invalid continuation byte

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17523 entries, 0 to 17522
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Indicator Value  17523 non-null  object
#  1   Indicator Name   17523 non-null  object
#  2   HDI category     16731 non-null  object
#  3   country          17523 non-null  object
#  4   Reference Name   17523 non-null  object
#  5   Reference        2134 non-null   object
# dtypes: object(6)
# memory usage: 958.3+ KB

# %%
from pandas_schema import Column, Schema
from pandas_schema.validation import LeadingWhitespaceValidation, TrailingWhitespaceValidation, IsDtypeValidation, InListValidation

# Nous ne testerons que ces colonnes
columns = ["country_name", "hdi_category", "values"]
# Et ces catégories
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]

schema = Schema([
    Column("country_name", [LeadingWhitespaceValidation(), TrailingWhitespaceValidation()]),
    Column("hdi_category", [InListValidation(hdi_categories)]),
    Column("values", [IsDtypeValidation(np.dtype(float)), IsDtypeValidation(np.dtype(int))])
])

errors = schema.validate(df[columns])

print(F"Nombre d'erreurs :  {len(errors)}")
# Juste les 10 premiers
for error in errors[:10]:
    print(error)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-bb165468ff6c> in <module>
#      13 ])
#      14
# ---> 15 errors = schema.validate(df[columns])
#      16
#      17 print(F"Nombre d'erreurs :  {len(errors)}")
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['country_name', 'hdi_category', 'values'], dtype='object')] are in the [columns]"

# %%
for l in method.citation.split(","):
    print(l)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-b2f8433945ee> in <module>
# ----> 1 for l in method.citation.split(","):
#       2     print(l)
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in citation(self)
#     823                 # Validate the input and output
#     824                 self.validate_input_data
# --> 825                 self.validate_transform
#     826                 citation = []
#     827                 ctn = self.schema_settings.get("constructors", {}).get("citation", {})
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in validate_transform(self)
#    2085                 bool: True for validates
#    2086 		"""
# -> 2087                 df = self.perform_transform
#    2088                 # Save temporary file ... has to save & load for checksum validation
#    2089                 _id = str(uuid.uuid4())
#
# ~\Anaconda3\envs\datascience\lib\site-packages\whyqd\method\method.py in perform_transform(self)
#    1809                 if self.schema_settings["input_data"][0].get("key"):
#    1810                         set_dtypes[self.schema_settings["input_data"][0]["key"]] = object
# -> 1811 		df = _c.get_dataframe(self.directory + self.schema_settings["working_data"]["file"],
#    1812 							dtype=set_dtypes)
#    1813                 # Begin transformations + keep track if any need filters
#
# KeyError: 'working_data'
