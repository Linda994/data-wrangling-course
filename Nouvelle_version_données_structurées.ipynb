# %%
import pandas as pd
import numpy as np

# %%
data = "HDR 2007-2008 Table 11.xlsx"

df = pd.read_excel(data)
df.head(12)
# Out:
#                                       Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                                            NaN        NaN         NaN
# 1   11  Commitment to education: public spending        NaN         NaN
# 2                                            NaN        NaN         NaN
# 3                                            NaN        NaN         NaN
# 4                                            NaN        NaN         NaN
# 5                                            NaN        NaN         NaN
# 6                                       HDI rank        NaN         NaN
# 7                                            NaN        NaN         NaN
# 8                         HIGH HUMAN DEVELOPMENT        NaN         NaN
# 9                                              1    Iceland         NaN
# 10                                             2     Norway         NaN
# 11                                             3  Australia         NaN
#
# ...

# %%
Entête=df.loc[1:2,:]

# %%
Entête
# Out:
#                                      Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 1  11  Commitment to education: public spending        NaN         NaN
# 2                                           NaN        NaN         NaN
#
#   Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 1        NaN         NaN        NaN        NaN        NaN        NaN
# 2        NaN         NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
#
# [2 rows x 33 columns]

# %%
baspage=df.loc[190:194,:]

# %%
baspage
# Out:
#                                             Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 190                                              NOTES        NaN         NaN
# 191                                                NaN        NaN         NaN
# 192  a. Expenditures by level may not sum to 100 as...        NaN         NaN
# 193                                                NaN        NaN         NaN
# 194  SOURCES\nColumns 1–4, 7, 9 and 10: UNESCO Inst...        NaN         NaN
#
#     Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 190        NaN         NaN        NaN        NaN        NaN        NaN
# 191        NaN         NaN        NaN        NaN        NaN        NaN
# 192        NaN         NaN        NaN        NaN        NaN        NaN
# 193        NaN         NaN        NaN        NaN        NaN        NaN
# 194        NaN         NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df=pd.read_excel(data, header=3)
df=df.dropna(how="all", axis=1)
df=df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1                          Unnamed: 3  \
# 0                     NaN        NaN  Public expenditure on education
# 1                     NaN        NaN                       As a % of GDP
# 2                HDI rank        NaN                                 NaN
# 3                     NaN        NaN                                1991
# 4  HIGH HUMAN DEVELOPMENT        NaN                                 NaN
# 5                       1    Iceland                                  ..
#
#   Unnamed: 5 Unnamed: 6                              Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN                                     NaN        NaN
# 1        NaN        NaN  As a % of total government expenditure        NaN
# 2        NaN        NaN                                     NaN        NaN
# 3  2002-05 b        NaN                                    1991        NaN
# 4        NaN        NaN                                     NaN        NaN
# ...

# %%
columns=[]
for c in df.columns:
    columns.append([str(v) for v in df[c][:5] if pd.notnull(v)])
columns
# Out:
# [['HDI rank', 'HIGH HUMAN DEVELOPMENT'],
#  [],
#  ['Public expenditure on education   ', 'As a % of GDP', '1991'],
#  ['2002-05 b'],
#  [],
#  ['As a % of total government expenditure', '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Current public expenditure on education by levela                                                                              (% of total current public expenditure on education) ',
#   'Pre-primary                           and primary',
#   '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Secondary and post-secondary non-tertiary                    ', '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Tertiary                          ', '1991'],
#  [],
#  ['2002-05 b'],
#  []]

# %%
columns=[
    "HDI rank",
    "country",
    "PEE _% _GDP_1991",
    "PEE _% _GDP_2002_2005b",
    "Reference 1",
    "PEE _% _TGE_1991 ",
    "Reference 2",
    "PEE _% _TGE_2002_2005b",
    "Reference 3",
    "current_PEE_by_primary_1991",
    "Reference 4",
    "current_PEE_by_primary_2002_2005b",
    "Reference 5",
    "current_PEE_by_secondary_1991",
    "Reference 6",
    "current_PEE_by_secondary_2002_2005b",
    "Reference 7",
    "current_PEE_by_Tertiary_1991",
    "Reference 8",
    "current_PEE_by_Tertiary_2002_2005b",
    "Reference 9"
]
df.columns = columns
df = df.drop(np.arange(5), axis=0).reset_index(drop=True)
df.head()
# Out:
#   HDI rank    country PEE _% _GDP_1991 PEE _% _GDP_2002_2005b Reference 1  \
# 0        1    Iceland               ..                    8.1         NaN
# 1        2     Norway              7.1                    7.7         NaN
# 2        3  Australia              4.9                    4.7         NaN
# 3        4     Canada              6.5                    5.2         NaN
# 4        5    Ireland              5.0                    4.8         NaN
#
#   PEE _% _TGE_1991  Reference 2 PEE _% _TGE_2002_2005b Reference 3  \
# 0                ..         NaN                   16.6         NaN
# 1              14.6         NaN                   16.6         NaN
# 2              14.8         NaN                   13.3           c
# 3              14.2         NaN                   12.5           c
# 4               9.7         NaN                   14.0         NaN
#
#   current_PEE_by_primary_1991  ... current_PEE_by_primary_2002_2005b  \
# ...

# %%
mycolumns=['Reference 1', 'Reference 2', 'Reference 3', 'Reference 4', 'Reference 5', 'Reference 6', 'Reference 7', 'Reference 8', 'Reference 9']
df[mycolumns]
# Out:
#     Reference 1 Reference 2 Reference 3 Reference 4 Reference 5 Reference 6  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN           c         NaN         NaN         NaN
# 3           NaN         NaN           c           d         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 177         NaN         NaN         NaN         NaN         NaN         NaN
# 178           e         NaN         NaN         NaN           e         NaN
# 179         NaN         NaN         NaN         NaN         NaN         NaN
# 180         NaN         NaN         NaN         NaN         NaN         NaN
# 181         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Reference 7 Reference 8 Reference 9
# ...

# %%
df.tail(30)
# Out:
#                                               HDI rank  \
# 152                                                152
# 153                                                153
# 154                                                154
# 155                                                155
# 156                              LOW HUMAN DEVELOPMENT
# 157                                                156
# 158                                                157
# 159                                                158
# 160                                                159
# 161                                                160
# 162                                                161
# 163                                                162
# 164                                                163
# 165                                                164
# 166                                                165
# 167                                                166
# ...

# %%
df=df.drop(np.arange(179,len(df)), axis=0).reset_index(drop=True)

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
df.loc[:, "HDI category"] = np.where(df["HDI rank"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] > 70,
                                              "MEDIUM HUMAN DEVELOPMENT",
                                              "HIGH HUMAN DEVELOPMENT"
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
#   HDI rank    country PEE _% _GDP_1991 PEE _% _GDP_2002_2005b Reference 1  \
# 0        1    Iceland               ..                    8.1         NaN
# 1        2     Norway              7.1                    7.7         NaN
# 2        3  Australia              4.9                    4.7         NaN
# 3        4     Canada              6.5                    5.2         NaN
# 4        5    Ireland              5.0                    4.8         NaN
#
#   PEE _% _TGE_1991  Reference 2 PEE _% _TGE_2002_2005b Reference 3  \
# 0                ..         NaN                   16.6         NaN
# 1              14.6         NaN                   16.6         NaN
# 2              14.8         NaN                   13.3           c
# 3              14.2         NaN                   12.5           c
# 4               9.7         NaN                   14.0         NaN
#
#   current_PEE_by_primary_1991  ... Reference 5 current_PEE_by_secondary_1991  \
# ...

# %%
destination="Nouv_education_public_spending_per_level_of_HDI.csv"
df.to_csv(destination, index=False)
