# %%
import pandas as pd
import numpy as np

# %%
data = "HDR 2007-2008 Table 11.xlsx"

df = pd.read_excel(data)
df.head(12)
# Out:
#                                       Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                                            NaN        NaN         NaN
# 1   11  Commitment to education: public spending        NaN         NaN
# 2                                            NaN        NaN         NaN
# 3                                            NaN        NaN         NaN
# 4                                            NaN        NaN         NaN
# 5                                            NaN        NaN         NaN
# 6                                       HDI rank        NaN         NaN
# 7                                            NaN        NaN         NaN
# 8                         HIGH HUMAN DEVELOPMENT        NaN         NaN
# 9                                              1    Iceland         NaN
# 10                                             2     Norway         NaN
# 11                                             3  Australia         NaN
#
# ...

# %%
Entête=df.loc[1:2,:]

# %%
Entête
# Out:
#                                      Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 1  11  Commitment to education: public spending        NaN         NaN
# 2                                           NaN        NaN         NaN
#
#   Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 1        NaN         NaN        NaN        NaN        NaN        NaN
# 2        NaN         NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
#
# [2 rows x 33 columns]

# %%
baspage=df.loc[190:194,:]

# %%
baspage
# Out:
#                                             Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 190                                              NOTES        NaN         NaN
# 191                                                NaN        NaN         NaN
# 192  a. Expenditures by level may not sum to 100 as...        NaN         NaN
# 193                                                NaN        NaN         NaN
# 194  SOURCES\nColumns 1–4, 7, 9 and 10: UNESCO Inst...        NaN         NaN
#
#     Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 190        NaN         NaN        NaN        NaN        NaN        NaN
# 191        NaN         NaN        NaN        NaN        NaN        NaN
# 192        NaN         NaN        NaN        NaN        NaN        NaN
# 193        NaN         NaN        NaN        NaN        NaN        NaN
# 194        NaN         NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df=pd.read_excel(data, header=3)
df=df.dropna(how="all", axis=1)
df=df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1                          Unnamed: 3  \
# 0                     NaN        NaN  Public expenditure on education
# 1                     NaN        NaN                       As a % of GDP
# 2                HDI rank        NaN                                 NaN
# 3                     NaN        NaN                                1991
# 4  HIGH HUMAN DEVELOPMENT        NaN                                 NaN
# 5                       1    Iceland                                  ..
#
#   Unnamed: 5 Unnamed: 6                              Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN                                     NaN        NaN
# 1        NaN        NaN  As a % of total government expenditure        NaN
# 2        NaN        NaN                                     NaN        NaN
# 3  2002-05 b        NaN                                    1991        NaN
# 4        NaN        NaN                                     NaN        NaN
# ...

# %%
columns=[]
for c in df.columns:
    columns.append([str(v) for v in df[c][:5] if pd.notnull(v)])
columns
# Out:
# [['HDI rank', 'HIGH HUMAN DEVELOPMENT'],
#  [],
#  ['Public expenditure on education   ', 'As a % of GDP', '1991'],
#  ['2002-05 b'],
#  [],
#  ['As a % of total government expenditure', '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Current public expenditure on education by levela                                                                              (% of total current public expenditure on education) ',
#   'Pre-primary                           and primary',
#   '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Secondary and post-secondary non-tertiary                    ', '1991'],
#  [],
#  ['2002-05 b'],
#  [],
#  ['Tertiary                          ', '1991'],
#  [],
#  ['2002-05 b'],
#  []]

# %%
columns=[
    "HDI rank",
    "country",
    "Public expenditure on education-As a % of GDP-1991",
    "Public expenditure on education-As a % of GDP-2002-05",
    "Reference 1",
    "Public expenditure on education-As a % of total government expenditure-1991",
    "Reference 2",
    "Public expenditure on education-As a % of total government expenditure-2002-05",
    "Reference 3",
    "Current public expenditure on education by level (% of total current public expenditure on education) Pre-primary-and primary-1991",
    "Reference 4",
    "Current public expenditure on education by level (% of total current public expenditure on education) Pre-primary-and primary-2002-05",
    "Reference 5",
    "Current public expenditure on education by level (% of total current public expenditure on education) Secondary and post-secondary non-tertiary-1991",
    "Reference 6",
    "Current public expenditure on education by level (% of total current public expenditure on education) Secondary and post-secondary non-tertiary-2002-05",
    "Reference 7",
    "Current public expenditure on education by level (% of total current public expenditure on education) Tertiary-1991",
    "Reference 8",
    "Current public expenditure on education by level (% of total current public expenditure on education) Tertiary-2002-05",
    "Reference 9"
]
df.columns = columns
df = df.drop(np.arange(5), axis=0).reset_index(drop=True)
df.head()
# Out:
#   HDI rank    country Public expenditure on education-As a % of GDP-1991  \
# 0        1    Iceland                                                 ..
# 1        2     Norway                                                7.1
# 2        3  Australia                                                4.9
# 3        4     Canada                                                6.5
# 4        5    Ireland                                                5.0
#
#   Public expenditure on education-As a % of GDP-2002-05 Reference 1  \
# 0                                                8.1            NaN
# 1                                                7.7            NaN
# 2                                                4.7            NaN
# 3                                                5.2            NaN
# 4                                                4.8            NaN
#
#   Public expenditure on education-As a % of total government expenditure-1991  \
# ...

# %%
mycolumns=['Reference 1', 'Reference 2', 'Reference 3', 'Reference 4', 'Reference 5', 'Reference 6', 'Reference 7', 'Reference 8', 'Reference 9']
df[mycolumns]
# Out:
#     Reference 1 Reference 2 Reference 3 Reference 4 Reference 5 Reference 6  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN           c         NaN         NaN         NaN
# 3           NaN         NaN           c           d         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 120         NaN         NaN         NaN         NaN         NaN         NaN
# 121         NaN         NaN         NaN         NaN           e         NaN
# 122         NaN         NaN         NaN         NaN         NaN         NaN
# 123         NaN         NaN         NaN         NaN         NaN         NaN
# 124         NaN         NaN           c         NaN         c,e         NaN
#
#     Reference 7 Reference 8 Reference 9
# ...

# %%
df.drop(['Reference 1', 'Reference 2', 'Reference 3', 'Reference 4', 'Reference 5', 'Reference 6', 'Reference 7', 'Reference 8', 'Reference 9'], axis=1, inplace=True)

# %%
df.tail(30)
# Out:
#     HDI rank                           country  \
# 95        96                           Georgia
# 96        97                            Guyana
# 97        98                        Azerbaijan
# 98        99                         Sri Lanka
# 99       100                          Maldives
# 100      101                           Jamaica
# 101      102                        Cape Verde
# 102      103                       El Salvador
# 103      104                           Algeria
# 104      105                          Viet Nam
# 105      106  Occupied Palestinian Territories
# 106      107                         Indonesia
# 107      108              Syrian Arab Republic
# 108      109                      Turkmenistan
# 109      110                         Nicaragua
# 110      111                           Moldova
# 111      112                             Egypt
# 112      113                        Uzbekistan
# 113      114                          Mongolia
# ...

# %%
df=df.drop(np.arange(126,len(df)), axis=0).reset_index(drop=True)

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
# Se débarrasser des rangées avec les catégories HDI
# https://stackoverflow.com/a/27360130 & https://stackoverflow.com/a/12098586
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
# Référence pour np.where https://docs.scipy.org/doc/numpy/reference/generated/numpy.where.html
# Pensez que cela ressemble à une déclaration du type "if" : where(test est vrai, vrai-quelque chose, faux-quelque chose)
# ceci peut aussi être imbriqué : where(test is true, true-thing, where(new-test is true, true-thing, false-thing))
df.loc[:, "HDI category"] = np.where(df["HDI rank"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] > 70,
                                              "MEDIUM HUMAN DEVELOPMENT",
                                              "HIGH HUMAN DEVELOPMENT"
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
#   HDI rank    country Public expenditure on education-As a % of GDP-1991  \
# 0        1    Iceland                                                 ..
# 1        2     Norway                                                7.1
# 2        3  Australia                                                4.9
# 3        4     Canada                                                6.5
# 4        5    Ireland                                                5.0
#
#   Public expenditure on education-As a % of GDP-2002-05  \
# 0                                                8.1
# 1                                                7.7
# 2                                                4.7
# 3                                                5.2
# 4                                                4.8
#
#   Public expenditure on education-As a % of total government expenditure-1991  \
# 0                                                 ..
# 1                                               14.6
# ...

# %%
df.tail(30)
# Out:
#     HDI rank                           country  \
# 95        96                           Georgia
# 96        97                            Guyana
# 97        98                        Azerbaijan
# 98        99                         Sri Lanka
# 99       100                          Maldives
# 100      101                           Jamaica
# 101      102                        Cape Verde
# 102      103                       El Salvador
# 103      104                           Algeria
# 104      105                          Viet Nam
# 105      106  Occupied Palestinian Territories
# 106      107                         Indonesia
# 107      108              Syrian Arab Republic
# 108      109                      Turkmenistan
# 109      110                         Nicaragua
# 110      111                           Moldova
# 111      112                             Egypt
# 112      113                        Uzbekistan
# 113      114                          Mongolia
# ...

# %%
destination="education_public_spending_per_level_of_HDI.csv"
df.to_csv(destination, index=False)
